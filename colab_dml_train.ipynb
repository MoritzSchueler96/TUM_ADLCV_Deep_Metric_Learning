# %% [markdown]
# # Mount GDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Branch Setup
# Fetch & checkout the branch that you need.

# %%
# !git clone https://github.com/MoritzSchueler96/TUM_ADLCV_Deep_Metric_Learning.git
# Out:
# fatal: destination path 'TUM_ADLCV_Deep_Metric_Learning' already exists and is not an empty directory.

# %%
# %cd TUM_ADLCV_Deep_Metric_Learning/
# Out:
# /content/TUM_ADLCV_Deep_Metric_Learning

# %%
# !git fetch
# !git branch
# Out:
# * main

# %%
# !git checkout moritz
# Out:
# Branch 'moritz' set up to track remote branch 'moritz' from 'origin'.
# Switched to a new branch 'moritz'

# %% [markdown]
# # Install requirements

# %%
pip install torch==1.10.0+cu111 torchvision==0.11.1+cu111 torchaudio==0.10.0+cu111 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/pyg-team/pytorch_geometric (to revision e8915ad1cb5831c33c77f0fa69ee8a2267074647) to /tmp/pip-install-7w04xjs3/torch-geometric_8495118a91454374984f3536c7c22299
#   Running command git clone -q https://github.com/pyg-team/pytorch_geometric /tmp/pip-install-7w04xjs3/torch-geometric_8495118a91454374984f3536c7c22299
#   Running command git rev-parse -q --verify 'sha^e8915ad1cb5831c33c77f0fa69ee8a2267074647'
#   Running command git fetch -q https://github.com/pyg-team/pytorch_geometric e8915ad1cb5831c33c77f0fa69ee8a2267074647
#   Running command git checkout -q e8915ad1cb5831c33c77f0fa69ee8a2267074647
# ...
#      |████████████████████████████████| 11.2 MB 4.8 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 33.0 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 37.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 44.6 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 269 kB/s
# ...

# %%
#!pip install -U PyYAML
# !pip install torch-scatter==2.0.5 -f https://pytorch-geometric.com/whl/torch-1.5.0+cu110.html
# !pip install einops
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# %cd ..
# Out:
# ...
#      |████████████████████████████████| 596 kB 15.5 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.5.0+cu110.html
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.5-cp37-cp37m-linux_x86_64.whl size=13666035 sha256=8ec843251b8201da61ff57086042798f94b2ccf087cff71787262ee20ecf6946
#   Stored in directory: /root/.cache/pip/wheels/87/f5/48/3572b2f7cc0a5221be34807cf8137d261313729997cd00be84
# Successfully built torch-scatter
# ...

# %% [markdown]
# # Download & unzip datasets & best weights

# %%
import os

# %%
# CARS dataset
if not os.path.exists("/content/gdrive/My Drive/Colab Notebooks/CARS.zip") and not os.path.isfile("/content/gdrive/My Drive/Colab Notebooks/CARS.zip"):
  # !wget https://vision.in.tum.de/webshare/u/seidensc/intra_batch_connections/CARS.zip -P "/content/gdrive/My Drive/Colab Notebooks/"
if not os.path.exists("/content/gdrive/My Drive/Colab Notebooks/data/CARS/"): 
  if not os.path.exists("/content/TUM_ADLCV_Deep_Metric_Learning/data/"): os.mkdir("/content/TUM_ADLCV_Deep_Metric_Learning/data/")
  if not os.path.exists("/content/TUM_ADLCV_Deep_Metric_Learning/data/CARS/"): 
    # !unzip "/content/gdrive/My Drive/Colab Notebooks/CARS.zip" -d "/content/TUM_ADLCV_Deep_Metric_Learning/data/"

# %%
# best weights
if not os.path.exists("content/gdrive/My Drive/Colab Notebooks/best_weights.zip") and not os.path.isfile("/content/gdrive/My Drive/Colab Notebooks/best_weights.zip"):
  # !wget https://vision.in.tum.de/webshare/u/seidensc/intra_batch_connections/best_weights.zip -P "/content/gdrive/My Drive/Colab Notebooks/"
if not os.path.exists("/content/TUM_ADLCV_Deep_Metric_Learning/best_weights/"): 
  # !unzip "/content/gdrive/My Drive/Colab Notebooks/best_weights.zip" -d "/content/TUM_ADLCV_Deep_Metric_Learning/"

# %%
if not os.path.exists("/content/gdrive/My Drive/Colab Notebooks/data/CARS/"): 
  # !python3 train.py --config_path config/config_cars_train_gat.yaml --dataset_path "/content/TUM_ADLCV_Deep_Metric_Learning/data/CARS" --net_type resnet50 --is_apex 0 
else:
  # !python3 train.py --config_path config/config_cars_train_gat.yaml --dataset_path "/content/gdrive/My Drive/Colab Notebooks/data/CARS/" --net_type resnet50 --is_apex 0
# Out:
# 2021-12-23 12:17:22,131 - Switching to device cuda:0
#
# ******************************************************* Versions *******************************************************
# Torch version:  1.10.0+cu111
# Torch Cuda version:  11.1
# Cuda available:  True
# Using Cuda Device:  0 Name:  Tesla K80
# Torch Scatter version:  2.0.9
# Torch file:  /usr/local/lib/python3.7/dist-packages/torch/__init__.py
# Scikit learn version:  1.0.1
# Torchvision version:  0.11.1+cu111
# Torchvision file:  /usr/local/lib/python3.7/dist-packages/torchvision/__init__.py
# ************************************************************************************************************************
#
# 2021-12-23 12:17:22,132 - Search iter 1/1
# ...

# %%
if not os.path.exists("/content/gdrive/MyDrive/Colab Notebooks/colab_results/"):
  os.mkdir("/content/gdrive/MyDrive/Colab Notebooks/colab_results/")
# %cp -vr results/ "/content/gdrive/MyDrive/Colab Notebooks/colab_results/"
# %cp -vr results_nets/ "/content/gdrive/MyDrive/Colab Notebooks/colab_results/"
# %cp -vr results_nets_intermediate/ "/content/gdrive/MyDrive/Colab Notebooks/colab_results/"
# Out:
# 'results/' -> '/content/gdrive/MyDrive/Colab Notebooks/colab_results/results'
# 'results_nets/' -> '/content/gdrive/MyDrive/Colab Notebooks/colab_results/results_nets'
# 'results_nets_intermediate/' -> '/content/gdrive/MyDrive/Colab Notebooks/colab_results/results_nets_intermediate'

# %%
while True: pass
